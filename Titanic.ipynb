# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test['Survived'] = np.nan

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# 3  27.0      0      0   315154   8.6625   NaN        S       NaN
# 4  22.0      1      1  3101298  12.2875   NaN        S       NaN

# %%
print('test: {}, train: {}' .format(test.shape,train.shape))
# Out:
# test: (418, 12), train: (891, 12)

# %%
total = pd.concat([test,train],)

# %%
total.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# 3  27.0      0      0   315154   8.6625   NaN        S       NaN
# 4  22.0      1      1  3101298  12.2875   NaN        S       NaN

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
#  11  Survived     891 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
total.shape
# Out:
# (1309, 12)

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
#  11  Survived     891 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
total[total['Survived'].notna()]['Survived']
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %%
total['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
sns.countplot(x = 'Pclass', data = total, hue = 'Survived')

# %%
sns.pairplot(total)

# %%
total  = total.drop('Name',axis = 1)

# %%
total  = total.drop('Ticket',axis = 1)

# %%
total  = total.drop('Cabin',axis = 1)

# %%
total.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0          892       3    male  34.5      0      0   7.8292        Q       NaN
# 1          893       3  female  47.0      1      0   7.0000        S       NaN
# 2          894       2    male  62.0      0      0   9.6875        Q       NaN
# 3          895       3    male  27.0      0      0   8.6625        S       NaN
# 4          896       3  female  22.0      1      1  12.2875        S       NaN

# %%
sns.countplot(x = 'Sex', data = total, hue = 'Survived')

# %%
plt.figure(figsize = (10,6))
sns.distplot(total['Age'], bins = 40, hist_kws = dict(edgecolor = 'black'))

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'SibSp', data = total, hue = 'Survived', palette = 'plasma')

# %%
total = total.drop('PassengerId',axis = 1)

# %%
total.corr()
# Out:
#             Pclass       Age     SibSp     Parch      Fare  Survived  \
# Pclass    1.000000 -0.408106  0.060832  0.018322 -0.558629 -0.338481
# Age      -0.408106  1.000000 -0.243699 -0.150917  0.178740 -0.077221
# SibSp     0.060832 -0.243699  1.000000  0.373587  0.160238 -0.035322
# Parch     0.018322 -0.150917  0.373587  1.000000  0.221539  0.081629
# Fare     -0.558629  0.178740  0.160238  0.221539  1.000000  0.257307
# Survived -0.338481 -0.077221 -0.035322  0.081629  0.257307  1.000000
# male      0.124617  0.063645 -0.109609 -0.213125 -0.185523 -0.543351
# Q         0.230491 -0.019458 -0.048678 -0.100943 -0.130059  0.003650
# S         0.091320 -0.070001  0.073709  0.071881 -0.169922 -0.149683
#
#               male         Q         S
# Pclass    0.124617  0.230491  0.091320
# Age       0.063645 -0.019458 -0.070001
# SibSp    -0.109609 -0.048678  0.073709
# Parch    -0.213125 -0.100943  0.071881
# Fare     -0.185523 -0.130059 -0.169922
# ...

# %%
np.where((total.corr() > 0.5) |(total.corr() < -0.5))
# Out:
# (array([0, 1, 1, 2, 3, 4, 5, 5, 6], dtype=int64),
#  array([0, 1, 5, 2, 3, 4, 1, 5, 6], dtype=int64))

# %%
plt.figure(figsize = (10,6))
sns.heatmap(total.corr(), annot = True)

# %%
total.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Fare             1
# Embarked         0
# Survived       418
# dtype: int64

# %%
total['Embarked'].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
total.loc[total['Embarked'].isna(),'Embarked'] = 'S'

# %%
total['Sex'].value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
from pandas import get_dummies
df = total

# %%
total = df
sex = pd.get_dummies(total['Sex'],drop_first=True)
embark = pd.get_dummies(total['Embarked'], drop_first = True)

# %%
total = pd.concat([total.drop(['Sex','Embarked'],axis = 1), sex, embark], axis = 1)

# %%
total.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Survived  male  Q  S
# 0          892       3  34.5      0      0   7.8292       NaN     1  1  0
# 1          893       3  47.0      1      0   7.0000       NaN     0  0  1
# 2          894       2  62.0      0      0   9.6875       NaN     1  1  0
# 3          895       3  27.0      0      0   8.6625       NaN     1  0  1
# 4          896       3  22.0      1      1  12.2875       NaN     0  0  1

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
total.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Survived       418
# male             0
# Q                0
# S                0
# dtype: int64

# %%
total.loc[total['Fare'].isnull(),'Fare'] = total[total['Pclass'] == 3]['Fare'].mean()

# %%
total['Age'].fillna(total['Age'].mean(),inplace = True)

# %%
test = total[total['Survived'].isna()]

# %%
train = total[total['Survived'].notnull()]

# %%
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Survived  male  Q  S
# 0          892       3  34.5      0      0   7.8292       NaN     1  1  0
# 1          893       3  47.0      1      0   7.0000       NaN     0  0  1
# 2          894       2  62.0      0      0   9.6875       NaN     1  1  0
# 3          895       3  27.0      0      0   8.6625       NaN     1  0  1
# 4          896       3  22.0      1      1  12.2875       NaN     0  0  1

# %%
from sklearn.model_selection import train_test_split

# %%
X = train.drop('Survived',axis = 1)
y = train['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators= 200)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
train_predict = rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print (confusion_matrix(y_test, train_predict))
print(classification_report(y_test, train_predict))
# Out:
# [[159  16]
#  [ 35  85]]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.91      0.86       175
#          1.0       0.84      0.71      0.77       120
#
#     accuracy                           0.83       295
#    macro avg       0.83      0.81      0.82       295
# weighted avg       0.83      0.83      0.82       295

# %%
test
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch      Fare  Survived  male  \
# 0            892       3  34.500000      0      0    7.8292       NaN     1
# 1            893       3  47.000000      1      0    7.0000       NaN     0
# 2            894       2  62.000000      0      0    9.6875       NaN     1
# 3            895       3  27.000000      0      0    8.6625       NaN     1
# 4            896       3  22.000000      1      1   12.2875       NaN     0
# ..           ...     ...        ...    ...    ...       ...       ...   ...
# 413         1305       3  29.881138      0      0    8.0500       NaN     1
# 414         1306       1  39.000000      0      0  108.9000       NaN     0
# 415         1307       3  38.500000      0      0    7.2500       NaN     1
# 416         1308       3  29.881138      0      0    8.0500       NaN     1
# 417         1309       3  29.881138      1      1   22.3583       NaN     1
#
#      Q  S
# 0    1  0
# 1    0  1
# 2    1  0
# ...

# %%
test_predict = rf.predict(test.drop('Survived',axis = 1))

# %%
test = test.drop('Survived', axis = 1)

# %%
test['Survived'] = test_predict

# %%
test[['PassengerId','Survived']].to_csv('submission.csv', index = False)

# %%
test['Survived'] = test['Survived'].astype('int64')
